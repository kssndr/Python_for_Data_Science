# %% [markdown]
# Задание:
# Используя данные из train.csv, построить
# модель для предсказания цен на недвижимость (квартиры).
# С помощью полученной модели предсказать
# цены для квартир из файла test.csv.
#
# Целевая переменная:
# Price
#
# Основная метрика:
# R2 - коэффициент детерминации (sklearn.metrics.r2_score)
#
# Вспомогательная метрика:
# MSE - средняя квадратичная ошибка (sklearn.metrics.mean_squared_error)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import warnings
from sklearn.ensemble import RandomForestRegressor as RF
from sklearn.metrics import r2_score as r2
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# # ПОДГОТОВКА ДАННЫХ

# %%
url = '/Users/mac/Desktop/Python_for_Data_Science/Courswork/train.csv'
data = pd.read_csv(url)

# %%
url_test = '/Users/mac/Desktop/Python_for_Data_Science/Courswork/test.csv'
test = pd.read_csv(url_test)

# %%
print(data.shape, test.shape)
# Out:
# (10000, 20) (5000, 19)

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %% [markdown]
# - поиск пропущенных данных

# %%
data_na = data.isnull().sum()
data_na = data_na[data_na>0]
data_na.sort_values(ascending=False)
# Out:
# Healthcare_1    4798
# LifeSquare      2113
# dtype: int64

# %% [markdown]
# # - исправим во всей базе явные "опечатки"

# %% [markdown]
# проверим "опечатки" и выбросы по следующим признакам:
# 1. HouseYear - исправили ошибки в написании года
# 2. Rooms - проверка ошибок в определении кол-ва комнат через среднюю площадь комнаты (Через Square)
# 3. Square - есть наблюдения с перепутанными значениями Square и LifeSquare(общая площадь не может быть меньше жилой) (решено), есть описка со значениями меньше 10м2 - ошибка с запятой(исправил)
# 4. LifeSquare - в одном случае ошибка с запятой,
# 5. HouseFloor - ограничили высоту 48 этажами(самый восокий жилой дом в москве)
# 6. KitchenSquare - этот признак и LifeSquare используем для корректировки Square, так пологаю что Square больше связано с ценой нежели эти два признака
# 9. Social_2
# 10. Healthcare_1
# 11. Shops_1
# 12. Price
#
# ! есть сомнения в правильности менять местами Square и LifeSquare, потому что возможна ошибка в запятой LifeSquare и она поэтому перенесется - частично я это устранил после того как поменял местами -но если в последствии не будет хорошего результата на валидационной базе - пересмотрю это момент

# %% [markdown]
# **Исправление HouseYear

# %%
data.loc[data['HouseYear']>2020]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497        12.0   20052011   0.136330         B         B        30
# 4189         9.0       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1497      6141        10         262.0            3        6       B
# 4189      4756        16        2857.0            5        8       B
#
#               Price
# 1497  254084.534396
# 4189  243028.603096

# %%
data.loc[data['HouseYear']==20052011,'HouseYear']=2008
data.loc[data['HouseYear']==4968,'HouseYear']=1968

# %% [markdown]
# **Исправление этажности и этажей

# %%
data.loc[data['HouseFloor']>48, 'HouseFloor']=data['Floor']

# %% [markdown]
# **Исправление размеров кухни (временно отменено)

# %% [markdown]
# data.loc[data['Square']<=data['KitchenSquare'],'KitchenSquare']=data['Square']-data['LifeSquare']

# %% [markdown]
# **Исправление путаницы с размерами Square и LifeSquare

# %%
for i in range(data.shape[0]):
    if data['Square'].iloc[i] < data['LifeSquare'].iloc[i]:
        Life_sq = data['Square'].iloc[i]
        data['Square'].iloc[i] = data['LifeSquare'].iloc[i]
        data['LifeSquare'].iloc[i] = Life_sq

# %% [markdown]
# **Исправление количества комнат

# %%
#есть квартиры с количеством комнат=0
data.loc[data['Rooms']==0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397  12638          27    0.0  138.427694  136.215499            0.0      4
# 1981   7917          27    0.0  212.932361  211.231125            0.0      2
# 2269   7317          27    0.0   41.790881         NaN            0.0     13
# 3911    770          28    0.0   49.483501         NaN            0.0     16
# 4366    456           6    0.0   81.491446         NaN            0.0      4
# 4853   3224          27    0.0    2.377248    0.873147            0.0      1
# 6149   3159          88    0.0   38.697117   19.345131            9.0      9
# 8834   9443          27    0.0   87.762616   85.125471            0.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397         3.0       2016   0.075424         B         B        11
# 1981         3.0       2008   0.211401         B         B         9
# ...

# %%
 #узнаем какая средняя площадь квартир в зависимости от количества комнат
data.groupby(['Rooms']).mean()
# Out:
#                  Id  DistrictId      Square  LifeSquare  KitchenSquare  \
# Rooms
# 0.0     5615.500000   32.125000   81.620358   90.558075       1.125000
# 1.0     8406.774629   47.137652   41.463894   24.974719       6.525776
# 2.0     8399.308763   50.762371   56.924668   35.798421       5.636340
# 3.0     8351.163758   53.723937   80.489473   50.591484       6.801790
# 4.0     8311.353333   70.900000   98.453655   65.586096       8.506667
# 5.0     5438.611111   70.777778  122.614941   89.445712       9.222222
# 6.0    14003.000000   99.000000   59.414334   38.702244       6.000000
# 10.0   10396.000000   33.000000   59.964120   37.321877      10.000000
# 19.0    8491.000000    1.000000   42.006046   21.779288       7.000000
#
#            Floor  HouseFloor    HouseYear  Ecology_1   Social_1      Social_2  \
# Rooms
# 0.0     6.750000    4.625000  1991.125000   0.152049  14.750000   3180.250000
# 1.0     8.684480   13.052362  1986.784885   0.122414  23.470175   5108.685830
# ...

# %%
#cредняя площадь от кол-ва комнат не информативен потому что общая площадь Square включает 
# в себя LifeSquare и KitchenSquare. Поэтому смотри количество метров площади на комнату

Squer_per_rooms=data.loc[:,['Id', 'Square','Rooms']]
Squer_per_rooms.insert(3,'Squer_per_rooms',(data['Square']/data['Rooms']))
Squer_per_rooms.groupby(['Rooms']).mean()
# Out:
#                  Id      Square  Squer_per_rooms
# Rooms
# 0.0     5615.500000   81.620358              inf
# 1.0     8406.774629   41.463894        41.463894
# 2.0     8399.308763   56.924668        28.462334
# 3.0     8351.163758   80.489473        26.829824
# 4.0     8311.353333   98.453655        24.613414
# 5.0     5438.611111  122.614941        24.522988
# 6.0    14003.000000   59.414334         9.902389
# 10.0   10396.000000   59.964120         5.996412
# 19.0    8491.000000   42.006046         2.210845

# %%
#наблюдаем аномальное уменьшение площади на комнату и собственно присутсвие квартир с "нулевым" количеством комнат
# разобьем полученые данные на две категории small с аномально маленькими комнатами и normal + выведем среднбб цену 
# для проверки соотношения Square Price

Squer_per_rooms=data.loc[:,['Id', 'Square','Rooms','Price']]
Squer_per_rooms.insert(3,'Squer_per_rooms',(data['Square']/data['Rooms']))
Squer_per_rooms.insert(4,'Price_per_Squer',(data['Price']/data['Square']))
Squer_per_rooms.insert(5,'small_and_normal', 0)
for i in range(Squer_per_rooms.shape[0]):
    if Squer_per_rooms['Square'].iloc[i]<10:
        Squer_per_rooms['small_and_normal'].iloc[i]=1
        
Squer_per_rooms.groupby(['small_and_normal','Rooms']).mean()
# Out:
#                                   Id      Square  Squer_per_rooms  \
# small_and_normal Rooms
# 0                0.0     5957.142857   92.940802              inf
#                  1.0     8402.086533   41.533774        41.533774
#                  2.0     8399.308763   56.924668        28.462334
#                  3.0     8352.885855   80.522991        26.840997
#                  4.0     8311.353333   98.453655        24.613414
#                  5.0     5438.611111  122.614941        24.522988
#                  6.0    14003.000000   59.414334         9.902389
#                  10.0   10396.000000   59.964120         5.996412
#                  19.0    8491.000000   42.006046         2.210845
# 1                0.0     3224.000000    2.377248              inf
#                  1.0    10883.428571    4.547383         4.547383
#                  3.0     4504.000000    5.610772         1.870257
#
#                         Price_per_Squer          Price
# small_and_normal Rooms
# ...

# %%
# наблюдаем снижение средней цены при наличии квартир с комнатами выше 5 при чем размер Square и Price
# соотносятся с размерами 2 комнатных квартир (кроме одной)
data.loc[data['Rooms']>5]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 1454   8491           1   19.0  42.006046   21.779288            7.0     17
# 2170  14003          99    6.0  59.414334   38.702244            6.0      7
# 8849  14865           9   10.0  60.871266   38.420681           10.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 377         22.0       2002   0.090799         B         B        74
# 1454        17.0       2014   0.007122         B         B         1
# 2170         9.0       1969   0.033494         B         B        66
# 8849         2.0       1994   0.161532         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 377      19083         2           NaN            5       15       B
# 1454       264         0           NaN            0        1       B
# ...

# %%
data.loc[data['Id']==8491,'Rooms']=1

# %%
data.loc[data['Rooms']>5, 'Rooms']=2

# %%
# посмотрим еще раз на квартиры с 0 комнатами
data.loc[data['Rooms']==0]
# видим что по величине Square и Price можно уточнить коли-чество комнат
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397  12638          27    0.0  138.427694  136.215499            0.0      4
# 1981   7917          27    0.0  212.932361  211.231125            0.0      2
# 2269   7317          27    0.0   41.790881         NaN            0.0     13
# 3911    770          28    0.0   49.483501         NaN            0.0     16
# 4366    456           6    0.0   81.491446         NaN            0.0      4
# 4853   3224          27    0.0    2.377248    0.873147            0.0      1
# 6149   3159          88    0.0   38.697117   19.345131            9.0      9
# 8834   9443          27    0.0   87.762616   85.125471            0.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397         3.0       2016   0.075424         B         B        11
# 1981         3.0       2008   0.211401         B         B         9
# ...

# %%
data.loc[data['Id']==12638,'Rooms']=4
data.loc[data['Id']==7917,'Rooms']=5
data.loc[data['Id']==7317,'Rooms']=1
data.loc[data['Id']==770,'Rooms']=1
data.loc[data['Id']==456,'Rooms']=3
data.loc[data['Id']==3159,'Rooms']=1
data.loc[data['Id']==9443,'Rooms']=3
data.loc[data['Id']==3224,'Rooms']=1

# %%
# теперь разберемся с "аномально маленькими" Square
(data.loc[data['Rooms']==3]).loc[data['Square']<10]
# скорее всего это маленькая трешка с ошибкой в запятой
# Out:
#         Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4900  4504          27    3.0  5.610772    4.390331            1.0      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4900        19.0       2016   0.211401         B         B         9
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4900      1892         0           NaN            0        1       B
#
#               Price
# 4900  161379.067034

# %%
data.loc[data['Id']==4504,'Square']=data.loc[data['Id']==4504,'Square']*10

# %%
# остались аномально маленькие однушки
data.loc[(data['Rooms']==1)&(data['Square']<10)]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 1316  11526          27    1.0  4.633498    1.969969            1.0     18
# 1608  10202           6    1.0  4.604943    2.596351            1.0      3
# 3413   9487           5    1.0  5.549458    5.129222            1.0      1
# 4853   3224          27    1.0  2.377248    0.873147            0.0      1
# 6392  14786           1    1.0  4.525736    1.136859            1.0      3
# 8283  15744          34    1.0  2.642219    1.988943            1.0     21
# 9294   6782          45    1.0  5.257278    2.954309            1.0      3
# 9613   7657          38    1.0  4.618547    4.502784            1.0     28
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1316         1.0       1977   0.011654         B         B         4
# 1608        25.0       2014   0.243205         B         B         5
# 3413         1.0       1977   0.150818         B         B        16
# ...

# %%
data.loc[(data['Rooms']==1)&(data['Square']<10),'Square']=data.loc[(data['Rooms']==1)&(data['Square']<10),'Square']*10

# %%
# проверяем как это все поменяла общую картину
data.describe()
# видно что появидись непонятные максимальные значения Square
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.888600     57.259322    36.048753
# std     4859.01902     43.587592      0.812315     77.294858    19.372398
# min        0.00000      0.000000      1.000000     15.988889     0.370619
# 25%     4169.50000     20.000000      1.000000     41.882259    22.765174
# 50%     8394.50000     36.000000      2.000000     52.652900    32.760108
# 75%    12592.50000     75.000000      2.000000     66.004634    45.029599
# max    16798.00000    209.000000      5.000000   7480.592129   638.163193
#
#        KitchenSquare         Floor    HouseFloor    HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean        6.273300      8.526700     12.579800   1984.86600      0.118858
# ...

# %%
data.loc[(data['Square']>200)&(data['Rooms']<4)]
# видим что соотношение Rooms Price с Square - не адекватные - ошибка с запятой
# Out:
#          Id  DistrictId  Rooms       Square  LifeSquare  KitchenSquare  Floor  \
# 590   14990          23    2.0   263.542020   48.449873            5.0      6
# 4262     28           9    2.0   604.705972         NaN            1.0     17
# 4328  16550          27    3.0  7480.592129   81.694417            1.0      9
# 4690   2307         102    1.0   410.639749  409.425181           10.0      4
# 6977  11602          30    2.0   641.065193  638.163193           10.0     20
# 8437  15886          85    3.0   461.463614   78.059331           10.0     12
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 590          5.0       1972   0.075779         B         B         6
# 4262        18.0       1977   0.161532         B         B        25
# 4328        17.0       2016   0.017647         B         B         2
# 4690         4.0       2016   0.238617         B         B        26
# 6977        19.0       2019   0.000078         B         B        22
# ...

# %%
LifeSquare_14990 = data.loc[(data['Id']==14990),'Square']/10
data.loc[(data['Id']==14990),'Square']=data.loc[(data['Id']==14990),'LifeSquare']
data.loc[(data['Id']==14990),'LifeSquare']=LifeSquare_14990

# %%
data.loc[(data['Id']==28),'Square']=data.loc[(data['Id']==28),'Square']/10

# %%
data.loc[(data['Id']==2307),'Square']=data.loc[(data['Id']==2307),'Square']/10
data.loc[(data['Id']==2307),'LifeSquare']=data.loc[(data['Id']==2307),'LifeSquare']/10

# %%
data.loc[(data['Id']==11602),'Square']=data.loc[(data['Id']==11602),'Square']/10
data.loc[(data['Id']==11602),'LifeSquare']=data.loc[(data['Id']==11602),'LifeSquare']/10

# %%
LifeSquare_16550 = data.loc[(data['Id']==16550),'Square']/100
data.loc[(data['Id']==16550),'Square']=data.loc[(data['Id']==16550),'LifeSquare']
data.loc[(data['Id']==16550),'LifeSquare']=LifeSquare_16550

# %%
LifeSquare_15886 = data.loc[(data['Id']==15886),'Square']/10
data.loc[(data['Id']==15886),'Square']=data.loc[(data['Id']==15886),'LifeSquare']
data.loc[(data['Id']==15886),'LifeSquare']=LifeSquare_15886

# %% [markdown]
# # - работа с частичными данными

# %% [markdown]
# - поиск пропущенных данных (проверка)

# %%
data_na = data.isnull().sum()
data_na = data_na[data_na>0]
data_na.sort_values(ascending=False)
# Out:
# Healthcare_1    4798
# LifeSquare      2113
# dtype: int64

# %% [markdown]
# решение вопроса частичного отсутствия данных в наблюдениях: LifeSquare, Healthcare_1.
# выявялем зависимости данных по этим признакам от других для моделирования недостояющих данных/принятия решения по этим данным
# для LifeSquare проверим соотношения Square LifeSquare KitchenSquare и заодно связь этих пораметров с Price
#
# !!!
# Временно, до первых результатов модели, на основании знакомства с данными, откажемся от параметров LifeSquare KitchenSquare, как от параметоров которые несущественно влияют на цены
#
# Поэтому заполним недостающие данные LifeSquare отношением средних Square к LifeSquare

# %% [markdown]
# ** Разберемся с кухнями

# %%
data.describe()
# уже по этим данным понятно что по меншей мере 50% данных не корректны (не может быть кухня 1 м2 )
# поэтому посчитаем среднее соотношение площади кухни к общей площади по данным где и рассчитаем значение для всех наблюдений
# где этот параметр меньше
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.888600     56.310505    35.921489
# std     4859.01902     43.587592      0.812315     19.116896    17.647415
# min        0.00000      0.000000      1.000000     15.988889     0.370619
# 25%     4169.50000     20.000000      1.000000     41.881659    22.765174
# 50%     8394.50000     36.000000      2.000000     52.633651    32.757783
# 75%    12592.50000     75.000000      2.000000     65.985903    45.020673
# max    16798.00000    209.000000      5.000000    275.645284   233.949309
#
#        KitchenSquare         Floor    HouseFloor    HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean        6.273300      8.526700     12.579800   1984.86600      0.118858
# ...

# %%
# уберем явные описки чтобы прояснитькартину
data.loc[((data['KitchenSquare'])>30)&(data['Square']<100)]
# эти некорректные данные пополнят нулевые кухни
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 227   16395           2    3.0  79.722243   44.731219           72.0     12
# 551    1315           6    1.0  48.128114   45.023531           48.0     21
# 1064  14656          62    1.0  47.100719   46.447960         2014.0      4
# 1077   9690          27    1.0  40.081042   37.834964           37.0     18
# 1369   2371          27    2.0  68.841073   64.234956           66.0      4
# 1455  12507          54    2.0  79.810535   79.578961           78.0     10
# 1860   4265         161    2.0  53.216778   32.644859           53.0      7
# 2916  12390          72    3.0  99.323558   97.490674           96.0     22
# 3379  16781          27    1.0  36.710539   36.138409           36.0     19
# 4079   6508          23    2.0  67.146049   33.959154           63.0      5
# 4110    299          27    2.0  66.787523   64.616662           60.0     14
# ...

# %%
data.loc[((data['KitchenSquare'])>30)&(data['Square']<100),'KitchenSquare']=0

# %%
data.loc[((data['KitchenSquare'])>50)&(data['Square']<300)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2969   7441          62    3.0  114.734473  112.589083          112.0      3
# 4651  12552          58    3.0  116.405693  113.109653          112.0      3
# 9895   2737          27    3.0  125.806981  123.430072          123.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2969         3.0       2015   0.072158         B         B         2
# 4651         3.0       2016   0.437885         B         B        23
# 9895        10.0       2015   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 2969       629         1           NaN            0        0       A
# 4651      5735         3        1084.0            0        5       B
# 9895       469         0           NaN            0        0       B
#
#               Price
# 2969  315245.521059
# 4651  296165.936689
# 9895  234194.837047

# %%
data.loc[((data['KitchenSquare'])>50)&(data['Square']<300),'KitchenSquare']=0

# %%
# теперь посмотрим кухни меньше 3 и обнулим их как не корректные
data.loc[((data['KitchenSquare'])<4),'KitchenSquare']=0

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.888600     56.310505    35.921489
# std     4859.01902     43.587592      0.812315     19.116896    17.647415
# min        0.00000      0.000000      1.000000     15.988889     0.370619
# 25%     4169.50000     20.000000      1.000000     41.881659    22.765174
# 50%     8394.50000     36.000000      2.000000     52.633651    32.757783
# 75%    12592.50000     75.000000      2.000000     65.985903    45.020673
# max    16798.00000    209.000000      5.000000    275.645284   233.949309
#
#        KitchenSquare         Floor    HouseFloor    HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean        5.441700      8.526700     12.579800   1984.86600      0.118858
# ...

# %%
kitchen_data=data.loc[:,['Id','KitchenSquare','LifeSquare','Square','Rooms','Price']]
tampl = kitchen_data.loc[(data['KitchenSquare']>0)].groupby(['Rooms']).mean()
print(tampl)
# Out:
#                 Id  KitchenSquare  LifeSquare      Square          Price
# Rooms
# 1.0    8356.453613       7.909791   22.753249   39.743797  169895.886859
# 2.0    8463.740880       7.649116   33.178273   53.032878  224512.965919
# 3.0    8378.600973       8.609489   48.082041   73.843841  302419.717910
# 4.0    8439.546154       9.684615   64.813564   96.622436  388431.538422
# 5.0    5336.000000      11.714286   91.201680  132.562346  447236.504643

# %%
# полученные нулевые значения заполним на основании соотношения в известных данных 
# KitchenSquare/Square с привязкой к количеству комнат
rooms = data['Rooms'].unique()
total_kitchen_koef=[]
for j in range(1,rooms.shape[0]+1):
    square_tot_kithen = data.loc[(data['KitchenSquare']>0)&(data['Rooms']==j)]['KitchenSquare'].mean()/data.loc[(data['KitchenSquare']>0)&(data['Rooms']==j)]['Square'].mean()
    total_kitchen_koef.append(square_tot_kithen)
total_kitchen_koef
# Out:
# [0.1990194974135795,
#  0.14423347305422146,
#  0.11659048269603213,
#  0.10023153825183087,
#  0.08836812314050946]

# %% [raw]
# почему от не сработал цикл - пришлось вручную
# for i in range(data.shape[0]):
#     if data['KitchenSquare'].iloc[i]==0 and data['Rooms'].iloc[i]==1:
#         for j in range(rooms.shape[0]):
# #             print(total_kitchen_koef[j])
#             data['KitchenSquare'].iloc[i]=data['Square'].iloc[i]*total_kitchen_koef[j]
#
# #             print(data['KitchenSquare'].iloc[i]=data['Square'].iloc[i]*square_tot_kithen)
#
# data.describe()

# %%
data.loc[(data['KitchenSquare']==0)&(data['Rooms']==1),'KitchenSquare']=data.loc[(data['KitchenSquare']==0)&(data['Rooms']==1),'Square']*total_kitchen_koef[0]
data.loc[(data['KitchenSquare']==0)&(data['Rooms']==2),'KitchenSquare']=data.loc[(data['KitchenSquare']==0)&(data['Rooms']==2),'Square']*total_kitchen_koef[1]
data.loc[(data['KitchenSquare']==0)&(data['Rooms']==3),'KitchenSquare']=data.loc[(data['KitchenSquare']==0)&(data['Rooms']==3),'Square']*total_kitchen_koef[2]
data.loc[(data['KitchenSquare']==0)&(data['Rooms']==4),'KitchenSquare']=data.loc[(data['KitchenSquare']==0)&(data['Rooms']==4),'Square']*total_kitchen_koef[3]
data.loc[(data['KitchenSquare']==0)&(data['Rooms']==5),'KitchenSquare']=data.loc[(data['KitchenSquare']==0)&(data['Rooms']==5),'Square']*total_kitchen_koef[4]

# %%
data.groupby(['Rooms']).mean()
# Out:
#                 Id  DistrictId      Square  LifeSquare  KitchenSquare  \
# Rooms
# 1.0    8401.633693   47.120216   41.438379   24.832879       8.247045
# 2.0    8401.780324   50.765645   56.582737   35.605134       8.161125
# 3.0    8348.122485   53.690657   77.036844   50.589169       8.981763
# 4.0    8340.006623   70.609272   98.718384   66.083486       9.894695
# 5.0    5569.052632   68.473684  127.368490   96.609560      11.255314
#
#           Floor  HouseFloor    HouseYear  Ecology_1   Social_1     Social_2  \
# Rooms
# 1.0    8.687871   13.043666  1986.793261   0.122379  23.461456  5106.453369
# 2.0    8.263971   12.098120  1982.847283   0.119449  24.540304  5297.677054
# 3.0    8.762629   12.725078  1985.155565   0.112221  26.493518  5741.119356
# 4.0    8.013245   11.854305  1985.403974   0.116733  31.450331  6910.794702
# 5.0    7.052632    9.105263  1982.736842   0.108493  27.526316  6280.947368
#
#         Social_3  Healthcare_1  Helthcare_2   Shops_1          Price
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %% [markdown]
# **разберемся с LifeSquare

# %%
data.loc[data['LifeSquare']<10].describe()
# очевидно имеет место ошибка с запятой
# Out:
#                  Id  DistrictId       Rooms      Square  LifeSquare  \
# count    208.000000  208.000000  208.000000  208.000000  208.000000
# mean    8333.163462   28.250000    1.716346   59.360232    3.458416
# std     4874.083130   25.110288    0.774798   18.880668    1.565503
# min       34.000000    0.000000    1.000000   16.117154    0.370619
# 25%     4338.500000    6.000000    1.000000   43.656357    2.060489
# 50%     8094.500000   27.000000    2.000000   58.708892    3.462688
# 75%    12559.750000   35.000000    2.000000   67.981801    4.760953
# max    16779.000000  169.000000    4.000000  127.651237    8.822988
#
#        KitchenSquare       Floor  HouseFloor    HouseYear   Ecology_1  \
# count     208.000000  208.000000  208.000000   208.000000  208.000000
# mean        9.344836   10.038462   11.072115  1996.341346    0.130460
# std         2.194761    6.172125    9.135565    19.777844    0.108078
# min         3.207628    1.000000    0.000000  1965.000000    0.000000
# ...

# %%
data.loc[data['LifeSquare']<10, 'LifeSquare']=data.loc[data['LifeSquare']<10, 'LifeSquare']*10

# %%
# осталось еще часть квартир с не корретными данными 
data.loc[data['LifeSquare']<10]
# обнулим эти данные чтобы потом заменить их по формуле в зависимости от количества комнат
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 26     4378          27    3.0  106.958871    6.418221      12.470386     17
# 4853   3224          27    1.0   23.772476    8.731467       4.731186      1
# 6609  13491           0    1.0   38.178277    3.706194       7.598222     19
# 9602   5112           6    2.0   63.591740    7.955395      10.000000     17
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 26           0.0       2018   0.072158         B         B         2
# 4853         0.0       1977   0.017647         B         B         2
# 6609        17.0       2016   0.006076         B         B        30
# 9602        17.0       2014   0.243205         B         B         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 26         629         1           NaN            0        0       A
# 4853       469         0           NaN            0        0       B
# ...

# %%
data.loc[data['LifeSquare']<10,'LifeSquare']=0

# %%
rooms = data['Rooms'].unique()
total_life_koef=[]
for j in range(1,rooms.shape[0]+1):
    square_tot_life = data.loc[(data['LifeSquare']>0)&(data['Rooms']==j)]['LifeSquare'].mean()/data.loc[(data['LifeSquare']>0)&(data['Rooms']==j)]['Square'].mean()
    total_life_koef.append(square_tot_life)
total_life_koef
# Out:
# [0.6371702864923724,
#  0.6673870042269638,
#  0.6817705174395662,
#  0.6803724737533887,
#  0.7363900948101896]

# %%
data.loc[data['LifeSquare']==0].groupby(['Rooms']).mean()
# Out:
#            Id  DistrictId      Square  LifeSquare  KitchenSquare  Floor  \
# Rooms
# 1.0    8357.5        13.5   30.975377         0.0       6.164704   10.0
# 2.0    5112.0         6.0   63.591740         0.0      10.000000   17.0
# 3.0    4378.0        27.0  106.958871         0.0      12.470386   17.0
#
#        HouseFloor  HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# Rooms
# 1.0           8.5     1996.5   0.011862      16.0    2877.0       0.0
# 2.0          17.0     2014.0   0.243205       5.0    1564.0       0.0
# 3.0           0.0     2018.0   0.072158       2.0     629.0       1.0
#
#        Healthcare_1  Helthcare_2  Shops_1          Price
# Rooms
# 1.0           645.0          3.0      3.0  115865.614396
# 2.0           540.0          0.0      0.0  174741.998061
# 3.0             NaN          0.0      0.0  337299.867936

# %%
# исправил нулевые LifeSquare
data.loc[(data['LifeSquare']==0)&(data['Rooms']==1),'LifeSquare']=data.loc[(data['LifeSquare']==0)&(data['Rooms']==1),'Square']*total_life_koef[0]
data.loc[(data['LifeSquare']==0)&(data['Rooms']==2),'LifeSquare']=data.loc[(data['LifeSquare']==0)&(data['Rooms']==2),'Square']*total_life_koef[1]
data.loc[(data['LifeSquare']==0)&(data['Rooms']==3),'LifeSquare']=data.loc[(data['LifeSquare']==0)&(data['Rooms']==3),'Square']*total_life_koef[2]
data.loc[(data['LifeSquare']==0)&(data['Rooms']==4),'LifeSquare']=data.loc[(data['LifeSquare']==0)&(data['Rooms']==4),'Square']*total_life_koef[3]
data.loc[(data['LifeSquare']==0)&(data['Rooms']==5),'LifeSquare']=data.loc[(data['LifeSquare']==0)&(data['Rooms']==5),'Square']*total_life_koef[4]

# %%
# исправил NaN LifeSquare
data.loc[(data['LifeSquare'].isna())&(data['Rooms']==1),'LifeSquare']=data.loc[(data['LifeSquare'].isna())&(data['Rooms']==1),'Square']*total_life_koef[0]
data.loc[(data['LifeSquare'].isna())&(data['Rooms']==2),'LifeSquare']=data.loc[(data['LifeSquare'].isna())&(data['Rooms']==2),'Square']*total_life_koef[1]
data.loc[(data['LifeSquare'].isna())&(data['Rooms']==3),'LifeSquare']=data.loc[(data['LifeSquare'].isna())&(data['Rooms']==3),'Square']*total_life_koef[2]
data.loc[(data['LifeSquare'].isna())&(data['Rooms']==4),'LifeSquare']=data.loc[(data['LifeSquare'].isna())&(data['Rooms']==4),'Square']*total_life_koef[3]
data.loc[(data['LifeSquare'].isna())&(data['Rooms']==5),'LifeSquare']=data.loc[(data['LifeSquare'].isna())&(data['Rooms']==5),'Square']*total_life_koef[4]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       10000 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.888600     56.310505     37.400287
# std     4859.01902     43.587592      0.812315     19.116896     16.432182
# min        0.00000      0.000000      1.000000     15.988889     10.498673
# 25%     4169.50000     20.000000      1.000000     41.881659     25.177925
# 50%     8394.50000     36.000000      2.000000     52.633651     33.820654
# 75%    12592.50000     75.000000      2.000000     65.985903     45.427162
# max    16798.00000    209.000000      5.000000    275.645284    233.949309
#
#        KitchenSquare         Floor    HouseFloor    HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean        8.408634      8.526700     12.579800   1984.86600      0.118858
# ...

# %% [markdown]
# !!!(перепроверить при плохих результатах на валидационной базе)
# предположим что Healthcare_1 зависит от DistrictId и Ecology_1
# заполним недостающие данные средними данными по DistrictId

# %%
# обучим на имеющихся данных метод и предположим данные для недостающих наблюдени
# разделим всю дата базу на базу с данными по Healthcare_1

# %%
Healthcare_1_test = data.loc[data['Healthcare_1'].isna()]
Healthcare_1_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4798 entries, 0 to 9997
# Data columns (total 20 columns):
# Id               4798 non-null int64
# DistrictId       4798 non-null int64
# Rooms            4798 non-null float64
# Square           4798 non-null float64
# LifeSquare       4798 non-null float64
# KitchenSquare    4798 non-null float64
# Floor            4798 non-null int64
# HouseFloor       4798 non-null float64
# HouseYear        4798 non-null int64
# Ecology_1        4798 non-null float64
# Ecology_2        4798 non-null object
# Ecology_3        4798 non-null object
# Social_1         4798 non-null int64
# Social_2         4798 non-null int64
# Social_3         4798 non-null int64
# Healthcare_1     0 non-null float64
# Helthcare_2      4798 non-null int64
# Shops_1          4798 non-null int64
# Shops_2          4798 non-null object
# Price            4798 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 787.2+ KB

# %%
Healthcare_1_data = data.loc[data['Healthcare_1']>=0]
Healthcare_1_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5202 entries, 1 to 9999
# Data columns (total 20 columns):
# Id               5202 non-null int64
# DistrictId       5202 non-null int64
# Rooms            5202 non-null float64
# Square           5202 non-null float64
# LifeSquare       5202 non-null float64
# KitchenSquare    5202 non-null float64
# Floor            5202 non-null int64
# HouseFloor       5202 non-null float64
# HouseYear        5202 non-null int64
# Ecology_1        5202 non-null float64
# Ecology_2        5202 non-null object
# Ecology_3        5202 non-null object
# Social_1         5202 non-null int64
# Social_2         5202 non-null int64
# Social_3         5202 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      5202 non-null int64
# Shops_1          5202 non-null int64
# Shops_2          5202 non-null object
# Price            5202 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 853.5+ KB

# %%
# а базу с данными по Healthcare_1 на тестовую и валидационную
train_h1,valid_h1=train_test_split(Healthcare_1_data,test_size=0.3, random_state=42)
train_h1.shape, valid_h1.shape
# Out:
# ((3641, 20), (1561, 20))

# %%
# хорошая зависимость с 'DistrictId','HouseYear','Social_1', 'Social_2', 
# 'Social_3','Helthcare_2', 'Shops_1', 'Price'
#  будем использовать это при обучении
feats_for_h1=['DistrictId','HouseYear','Social_1', 'Social_2','Social_3','Helthcare_2', 'Shops_1', 'Price']
model_for_h1=RF(n_estimators=100,max_depth=30,random_state=42)

# %%
# обучение
model_for_h1.fit(train_h1.loc[:,feats_for_h1],train_h1['Healthcare_1'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=30,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
# предсказание
y_pred_h1=model_for_h1.predict(valid_h1.loc[:,feats_for_h1])

# %%
# оценка на валиде
r2(valid_h1['Healthcare_1'],y_pred_h1)
# Out:
# 0.9960110194741364

# %%
# оценка на трэйне
r2(train_h1['Healthcare_1'],model_for_h1.predict(train_h1.loc[:,feats_for_h1]))
# Out:
# 0.9996572742878872

# %%
# создание данных - на "тесте" и добавление данных в data как новая колонка
Healthcare_1_test['Healthcare_1']=model_for_h1.predict(Healthcare_1_test.loc[:,feats_for_h1])
Healthcare_1_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4798 entries, 0 to 9997
# Data columns (total 20 columns):
# Id               4798 non-null int64
# DistrictId       4798 non-null int64
# Rooms            4798 non-null float64
# Square           4798 non-null float64
# LifeSquare       4798 non-null float64
# KitchenSquare    4798 non-null float64
# Floor            4798 non-null int64
# HouseFloor       4798 non-null float64
# HouseYear        4798 non-null int64
# Ecology_1        4798 non-null float64
# Ecology_2        4798 non-null object
# Ecology_3        4798 non-null object
# Social_1         4798 non-null int64
# Social_2         4798 non-null int64
# Social_3         4798 non-null int64
# Healthcare_1     4798 non-null float64
# Helthcare_2      4798 non-null int64
# Shops_1          4798 non-null int64
# Shops_2          4798 non-null object
# Price            4798 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 787.2+ KB

# %%
Healthcare_1_test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   4798.000000  4798.000000  4798.000000  4798.000000  4798.000000
# mean    8386.307211    41.983535     1.853064    57.205667    38.651537
# std     4864.658955    37.386871     0.814888    19.646660    17.505512
# min        2.000000     1.000000     1.000000    17.414181    10.498673
# 25%     4144.250000    23.000000     1.000000    42.163311    25.981023
# 50%     8420.500000    27.000000     2.000000    53.736741    34.848470
# 75%    12589.500000    62.000000     2.000000    66.795761    46.565795
# max    16797.000000   208.000000     5.000000   212.932361   211.231125
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    4798.000000  4798.000000  4798.000000  4798.000000  4798.000000
# mean        8.740453     8.867653    12.811171  1987.670488     0.090077
# std         2.376743     5.358387     6.866257    17.684670     0.100627
# ...

# %%
# a подсуним вместо Healthcare_1_test настоящую data
data.loc[data['Healthcare_1'].isna(), 'Healthcare_1']=model_for_h1.predict(Healthcare_1_test.loc[:,feats_for_h1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-37c8fdad2bf5> in <module>
#       1 # a подсуним вместо Healthcare_1_test настоящую data
# ----> 2 data.loc[data['Healthcare_1'].isna(), 'Healthcare_1']=model_for_h1.predict(Healthcare_1_test.loc[:,feats_for_h1])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     609
#     610                     if len(labels) != len(value):
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       10000 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     10000 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %% [markdown]
# ## - разделим базу на тренировочную и валидационную части

# %%
train,valid=train_test_split(data,test_size=0.3, random_state=42)

# %%
train.shape, valid.shape
# Out:
# ((7000, 20), (3000, 20))

# %% [markdown]
# # ИССЛЕДОВАНИЕ

# %% [markdown]
# что влияет на цену:
# площадь
#     год
#        комнаты(планировка)
#             этаж + высота дома
#
# дистрикт
#     Экология + хелскеа
#         Социальное + Шопс

# %%
y_train = train.Price

# %%
vars = data.columns
# vars = numerical_features
figures_per_time = 4
count = 0 
y = y_train
for var in vars:
    x = train[var]
#     print(y.shape,x.shape)
    plt.figure(count//figures_per_time,figsize=(25,5))
    plt.subplot(1,figures_per_time,np.mod(count,4)+1)
    plt.scatter(x, y);
    plt.title('f model: T= {}'.format(var))
    count+=1

# %%
categorical_features = data.select_dtypes(include=['object']).columns
print(categorical_features)
numerical_features = data.select_dtypes(exclude = ["object"]).columns
print(numerical_features)

print("Numerical features : " + str(len(numerical_features)))
print("Categorical features : " + str(len(categorical_features)))
feat_num = data[numerical_features]
feat_cat = data[categorical_features]
# Out:
# Index(['Ecology_2', 'Ecology_3', 'Shops_2'], dtype='object')
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Social_1', 'Social_2',
#        'Social_3', 'Healthcare_1', 'Helthcare_2', 'Shops_1', 'Price'],
#       dtype='object')
# Numerical features : 17
# Categorical features : 3

# %% [markdown]
# статистика по категориальным признакам

# %%
vars_box = feat_cat
for var in vars_box:
    data = pd.concat([train['Price'], train[var]], axis=1)
    f, ax = plt.subplots(figsize=(8, 6))
    fig = sns.boxplot(x=var, y="Price", data=data)

# %%
train['Price'].describe()
# Out:
# count      7000.000000
# mean     214449.167390
# std       92924.798790
# min       59174.778028
# 25%      154599.240157
# 50%      192290.039215
# 75%      249080.956886
# max      627525.072788
# Name: Price, dtype: float64

# %%
sns.distplot(train['Price']);
#skewness and kurtosis
print("Skewness: %f" % train['Price'].skew())
print("Kurtosis: %f" % train['Price'].kurt())
# Out:
# Skewness: 1.378109
# Kurtosis: 2.262127

# %% [markdown]
# сравним данные с Price в кареляционной матрице

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=1, square=True);

# %%
corr_num = 20 #количество переменных 
cols_corr = corrmat.nlargest(corr_num, 'Price')['Price'].index
corr_mat_sales = np.corrcoef(train[cols_corr].values.T)
sns.set(font_scale=1.25)
f, ax = plt.subplots(figsize=(12, 9))
hm = sns.heatmap(corr_mat_sales, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 7}, yticklabels=cols_corr.values, xticklabels=cols_corr.values)
plt.show()

# %%
# графики для переменных с наибольшей кореляцией
var_num = 8
# vars = cols_corr[0:var_num]
vars = ['Square', 'Rooms', 'LifeSquare']

sns.set()
sns.pairplot(train[vars], size = 2.5)
plt.show();

# %% [markdown]
# - создание в модели для проверки гипотезы влияния на цены места и площади квартиры (пока только по двум признакам)
# нормализуем (попробывать потом стандартизацию)
#
# !!! по пробывать взять больше важных признаков

# %%
scaler=MinMaxScaler()
# train_scaled=scaler.fit_transform(train.loc[:,['Square','DistrictId']])
# train_scaled
# inertia_arr=[]
# for i in range(2,10):
#     temp_model=KMeans(n_clusters=i,random_state=10)
#     temp_model.fit(train_scaled)
#     temp_inertia=temp_model.inertia_
#     print(temp_inertia)
#     inertia_arr.append(temp_inertia)

          
# plt.plot([i for i in range(2,10)],inertia_arr)
# plt.title('INERTIA')

# from sklearn.cluster import AgglomerativeClustering

# model=AgglomerativeClustering(n_clusters=6)

# train['cluster_Square']=model.fit_predict(train_scaled)

# plt.scatter(train['Square'],train['DistrictId'],c=train['cluster_Square'])
# plt.xlabel('Square')
# plt.ylabel('DistrictId')
# plt.title('Train')


# from sklearn.neighbors import KNeighborsClassifier

# knn=KNeighborsClassifier(n_neighbors=6)

# knn.fit(train_scaled,train['cluster_Square'])


# valid_scaled=scaler.transform(valid.loc[:,['Square','DistrictId']])

# valid['cluster_Square']=knn.predict(valid_scaled)

# valid['cluster_Square'].hist(bins=6);

# %%
train[['DistrictId']]=train['DistrictId'].astype(float)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7000 entries, 9069 to 7270
# Data columns (total 20 columns):
# Id               7000 non-null int64
# DistrictId       7000 non-null float64
# Rooms            7000 non-null float64
# Square           7000 non-null float64
# LifeSquare       7000 non-null float64
# KitchenSquare    7000 non-null float64
# Floor            7000 non-null int64
# HouseFloor       7000 non-null float64
# HouseYear        7000 non-null int64
# Ecology_1        7000 non-null float64
# Ecology_2        7000 non-null object
# Ecology_3        7000 non-null object
# Social_1         7000 non-null int64
# Social_2         7000 non-null int64
# Social_3         7000 non-null int64
# Healthcare_1     7000 non-null float64
# Helthcare_2      7000 non-null int64
# Shops_1          7000 non-null int64
# Shops_2          7000 non-null object
# Price            7000 non-null float64
# dtypes: float64(9), int64(8), object(3)
# memory usage: 1.4+ MB

# %%
train_scaled=scaler.fit_transform(train.loc[:,['Square','DistrictId']])

# %%
train_scaled
# Out:
# array([[0.13840068, 0.11004785],
#        [0.79458984, 0.11004785],
#        [0.12778193, 0.41626794],
#        ...,
#        [0.36219305, 0.00478469],
#        [0.19051032, 0.44976077],
#        [0.38987494, 0.00956938]])

# %% [markdown]
# определим количество кластеров для разбиения

# %%
inertia_arr=[]
for i in range(2,10):
    temp_model=KMeans(n_clusters=i,random_state=10)
    temp_model.fit(train_scaled)
    temp_inertia=temp_model.inertia_
    print(temp_inertia)
    inertia_arr.append(temp_inertia)
# Out:
# 159.33320015470008
# 114.89483321060192
# 87.42857980482893
# 70.48671352989614
# 57.53180186763521
# 51.01881237714365
# 45.128256173609515
# 40.144158255437944

# %%
plt.plot([i for i in range(2,10)],inertia_arr)
plt.title('INERTIA')
# Out:
# Text(0.5, 1.0, 'INERTIA')

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model=AgglomerativeClustering(n_clusters=6)

# %%
train['cluster_Square']=model.fit_predict(train_scaled)

# %%
plt.scatter(train['Square'],train['DistrictId'],c=train['cluster_Square'])
plt.xlabel('Square')
plt.ylabel('DistrictId')
plt.title('Train')
# Out:
# Text(0.5, 1.0, 'Train')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7000 entries, 9069 to 7270
# Data columns (total 21 columns):
# Id                7000 non-null int64
# DistrictId        7000 non-null float64
# Rooms             7000 non-null float64
# Square            7000 non-null float64
# LifeSquare        7000 non-null float64
# KitchenSquare     7000 non-null float64
# Floor             7000 non-null int64
# HouseFloor        7000 non-null float64
# HouseYear         7000 non-null int64
# Ecology_1         7000 non-null float64
# Ecology_2         7000 non-null object
# Ecology_3         7000 non-null object
# Social_1          7000 non-null int64
# Social_2          7000 non-null int64
# Social_3          7000 non-null int64
# Healthcare_1      7000 non-null float64
# Helthcare_2       7000 non-null int64
# Shops_1           7000 non-null int64
# Shops_2           7000 non-null object
# Price             7000 non-null float64
# cluster_Square    7000 non-null int64
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=6)

# %%
knn.fit(train_scaled,train['cluster_Square'])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#            weights='uniform')

# %%
valid_scaled=scaler.transform(valid.loc[:,['Square','DistrictId']])

# %%
valid['cluster_Square']=knn.predict(valid_scaled)

# %%
valid['cluster_Square'].hist(bins=6);

# %% [markdown]
# у нас получился признак cluster_Square который участвуя в трениоровке модели размывает зависимость цены напрямую от дистрикта и площади

# %%
valid.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean    8377.215000    50.027333     1.893667    56.336110    37.527608
# std     4847.850029    43.224970     0.818077    19.567645    16.866009
# min        2.000000     0.000000     1.000000    16.698571    10.523868
# 25%     4153.750000    21.000000     1.000000    41.969292    25.341916
# 50%     8390.500000    34.000000     2.000000    52.300299    33.842594
# 75%    12656.250000    74.000000     2.000000    65.827437    45.602240
# max    16798.000000   208.000000     5.000000   275.645284   233.949309
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean        8.366496     8.539333    12.504000  1984.741667     0.121232
# std         2.454533     5.286313     6.596652    18.649795     0.119999
# ...

# %% [markdown]
# ### создадим еще один признак

# %% [markdown]
# ### выделение параметров, которые будут участвовать в тренировке

# %%
train.keys()
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2', 'Price', 'cluster_Square'],
#       dtype='object')

# %%
# feats=['DistrictId','Rooms', 'Square', 'LifeSquare', 'KitchenSquare','Square','Ecology_1','Social_1', 'Social_2', 'Social_3','Helthcare_2', 'Shops_1', 'cluster_Square']
feats=['DistrictId','Rooms', 'Square', 'LifeSquare', 'Social_1']

# %% [markdown]
# тренировка метода рандом форест на подготовленных (feats) к тренировке данных в тренировочной базе

# %%
from sklearn.ensemble import RandomForestRegressor as RF
model=RF(n_estimators=300,max_depth=100,random_state=42,max_features=3,min_samples_leaf=3,min_samples_split=8)

# %%
model.fit(train.loc[:,feats],train['Price'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=100,
#            max_features=3, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=3,
#            min_samples_split=8, min_weight_fraction_leaf=0.0,
#            n_estimators=300, n_jobs=None, oob_score=False, random_state=42,
#            verbose=0, warm_start=False)

# %% [markdown]
# ??? подбор гипер параметров - выбрать лучшие параметры с помощью кип серч для этой модели
# как определять лучшие пораметры - через r2??
# лучшие параметры{'bootstrap': True,
#  'max_depth': 100,
#  'max_features': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8,
#  'n_estimators': 300}

# %%
from sklearn.model_selection import RandomizedSearchCV
from pprint import pprint
# количество деревьев
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1400, num = 5)]
# количество признаков
max_features = ['auto', 'sqrt']
# максимальная глубина
max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
max_depth.append(None)
# макимальное количестов узлов
min_samples_split = [2, 5, 10]
# минимальное количестов листьев
min_samples_leaf = [1, 2, 4]
# метод селекци
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
pprint(random_grid)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [10, 35, 60, 85, 110, None],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4],
#  'min_samples_split': [2, 5, 10],
#  'n_estimators': [100, 425, 750, 1075, 1400]}

# %% [raw]
# rf_ = RF()
#
# rf_random = RandomizedSearchCV(estimator = rf_, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
#
# rf_random.fit(train.loc[:,feats],train['Price'])

# %%
from sklearn.model_selection import GridSearchCV
 
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

rf = RF()

grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
# Fit the grid search to the data
grid_search.fit(train.loc[:,feats],train['Price'])
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 288 candidates, totalling 864 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 864 out of 864 | elapsed: 23.3min finished
# {'bootstrap': True,
#  'max_depth': 100,
#  'max_features': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8,
#  'n_estimators': 300}

# %%
valid.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean    8377.215000    50.027333     1.893667    56.336110    37.527608
# std     4847.850029    43.224970     0.818077    19.567645    16.866009
# min        2.000000     0.000000     1.000000    16.698571    10.523868
# 25%     4153.750000    21.000000     1.000000    41.969292    25.341916
# 50%     8390.500000    34.000000     2.000000    52.300299    33.842594
# 75%    12656.250000    74.000000     2.000000    65.827437    45.602240
# max    16798.000000   208.000000     5.000000   275.645284   233.949309
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean        8.366496     8.539333    12.504000  1984.741667     0.121232
# std         2.454533     5.286313     6.596652    18.649795     0.119999
# ...

# %% [markdown]
# накатывание через def необходимых для моделирования данных на валидационные данные (добытых при разработки модели на тестовых данных)

# %% [markdown]
# valid=add_distr_info(valid, distr_info1)

# %% [markdown]
# valid=add_mean_price(valid,price_mean_by_distr_rooms,price_mean_by_rooms,price)

# %% [markdown]
# valid=dummies(valid)

# %% [markdown]
# Получение данных на обученной модели - предсказания по валидационныым данным по параметрам которые участвуют в моделировании

# %%
y_pred=model.predict(valid.loc[:,feats])

# %%
y_pred
# Out:
# array([194294.50130079, 333379.20871585, 219551.77541344, ...,
#        251998.26389141, 117248.05894955, 252713.27239544])

# %% [markdown]
# проверка модели на валидационном блоке

# %%
from sklearn.metrics import r2_score as r2

# %%
r2(valid['Price'],y_pred)
# Out:
# 0.702343697341657

# %%
r2(train['Price'],model.predict(train.loc[:,feats]))
# Out:
# 0.864354856191017

# %% [markdown]
# from sklearn.ensemble import RandomForestRegressor as RF
# model=RF(n_estimators=40,max_depth=10,random_state=42)
# r2(valid['Price'],y_pred)
# 0.6891002476531285
#
# r2(train['Price'],model.predict(train.loc[:,feats]))
# 0.8350266536262695
#
# from sklearn.ensemble import RandomForestRegressor as RF
# model=RF(n_estimators=1000,max_depth=400,random_state=42)
# 0.6836317090191373
# 0.959103719038321
#
#
# 70/30
# from sklearn.ensemble import RandomForestRegressor as RF
# model=RF(n_estimators=1000,max_depth=400,random_state=42)
# 0.6873716929872556
# 0.9584705539457815
#
# добавил параметры 'Square', 'LifeSquare', 'KitchenSquare',
#
# r2(valid['Price'],y_pred)
# Out[221]:
# 0.697948761959828
#
# r2(train['Price'],model.predict(train.loc[:,feats]))
# Out[222]:
# 0.9610493743763139

# %% [markdown]
# # Получение данных на тестовом наборе

# %% [markdown]
# #### Чистка данных

# %%
test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.449500    36.158810
# std     4832.674037    44.179466     0.838594    19.092787    17.825287
# min        1.000000     0.000000     0.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    23.092026
# 50%     8320.500000    37.000000     2.000000    52.921340    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %% [markdown]
# #### поиск пропущенных данных

# %%
test_na = test.isnull().sum()
test_na = test_na[test_na>0]
test_na.sort_values(ascending=False)
# Out:
# Healthcare_1    2377
# LifeSquare      1041
# dtype: int64

# %% [markdown]
# #### - исправим во всей базе явные "опечатки"

# %%
# исправление этажей
test.loc[test['HouseFloor']>48, 'HouseFloor']=test['Floor']

# %%
# Исправление путаницы с размерами Square и LifeSquare
for i in range(test.shape[0]):
    if test['Square'].iloc[i] < test['LifeSquare'].iloc[i]:
        Life_sq_t = test['Square'].iloc[i]
        test['Square'].iloc[i] = test['LifeSquare'].iloc[i]
        test['LifeSquare'].iloc[i] = Life_sq_t

# %%
#есть квартиры с количеством комнат=0
test.loc[test['Rooms']==0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2406   3343          58    0.0  116.824201  113.692424            0.0      3
# 2524  10729          27    0.0   76.345154   42.820796           12.0     14
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2406         3.0       1977   0.437885         B         B        23
# 2524         0.0       1977   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 2406      5735         3        1084.0            0        5       B
# 2524       469         0           NaN            0        0       B

# %%
 #узнаем какая средняя площадь квартир в зависимости от количества комнат
test.groupby(['Rooms']).mean()
# Out:
#                 Id  DistrictId      Square  LifeSquare  KitchenSquare  \
# Rooms
# 0.0    7036.000000   42.500000   96.584677   78.256610       6.000000
# 1.0    8376.291125   49.691916   41.029351   24.546782       5.307518
# 2.0    8498.000493   50.920197   56.929386   35.914865       6.150246
# 3.0    8317.183803   52.793449   77.261546   50.083019       6.538672
# 4.0    8407.777778   71.688889   94.526010   64.916940       7.933333
# 5.0    9533.428571   57.857143  115.788971   63.195393      10.571429
# 6.0    7425.500000   25.000000  167.101957  104.113552       8.000000
# 17.0   1435.000000  111.000000   52.866107   32.528342       8.000000
#
#            Floor  HouseFloor    HouseYear  Ecology_1   Social_1     Social_2  \
# Rooms
# 0.0     8.500000    1.500000  1977.000000   0.227766  12.500000  3102.000000
# 1.0     8.878462   12.791408  1985.986998   0.119710  23.955907  5214.457321
# 2.0     8.419212   12.420690  1982.649261   0.122305  24.505419  5277.280296
# ...

# %%
#cредняя площадь от кол-ва комнат не информативен потому что общая площадь Square включает 
# в себя LifeSquare и KitchenSquare. Поэтому смотри количество метров площади на комнату

Squer_per_rooms_t=test.loc[:,['Id', 'Square','Rooms']]
Squer_per_rooms_t.insert(3,'Squer_per_rooms',(test['Square']/test['Rooms']))
Squer_per_rooms_t.groupby(['Rooms']).mean()
# Out:
#                 Id      Square  Squer_per_rooms
# Rooms
# 0.0    7036.000000   96.584677              inf
# 1.0    8376.291125   41.029351        41.029351
# 2.0    8498.000493   56.929386        28.464693
# 3.0    8317.183803   77.261546        25.753849
# 4.0    8407.777778   94.526010        23.631502
# 5.0    9533.428571  115.788971        23.157794
# 6.0    7425.500000  167.101957        27.850326
# 17.0   1435.000000   52.866107         3.109771

# %%
#наблюдаем аномальное уменьшение площади на комнату и собственно присутсвие квартир с "нулевым" количеством комнат
# разобьем полученые данные на две категории small с аномально маленькими комнатами и normal + выведем среднбб цену 
# для проверки соотношения Square Price

Squer_per_rooms_t=test.loc[:,['Id', 'Square','Rooms']]
Squer_per_rooms_t.insert(3,'Squer_per_rooms',(test['Square']/test['Rooms']))
Squer_per_rooms_t.insert(4,'small_and_normal', 0)
for i in range(Squer_per_rooms_t.shape[0]):
    if Squer_per_rooms_t['Square'].iloc[i]<10:
        Squer_per_rooms_t['small_and_normal'].iloc[i]=1
        
Squer_per_rooms_t.groupby(['small_and_normal','Rooms']).mean()
# Out:
#                                  Id      Square  Squer_per_rooms
# small_and_normal Rooms
# 0                1.0    8376.291125   41.165216        41.165216
#                  2.0    8494.522895   56.927385        28.463693
#                  3.0    8319.376364   77.260713        25.753571
#                  4.0    8407.777778   94.526010        23.631502
#                  5.0    8759.625000  115.918374        23.183675
#                  6.0    7425.500000  167.101957        27.850326

# %%
# наблюдаем снижение средней цены при наличии квартир с комнатами выше 5 при чем размер Square и Price
# соотносятся с размерами 2 комнатных квартир (кроме одной)
test.loc[test['Rooms']>5]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2071  10793          23    6.0  110.750226         NaN            0.0      2
# 3217   4058          27    6.0  223.453689  104.113552           16.0      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2071         2.0       2015   0.014073         B         B         2
# 3217         2.0       2017   0.041116         B         B        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 2071       475         0           NaN            0        0       B
# 3217     14892         4           NaN            1        4       B

# %%
test.loc[test['Rooms']==17, 'Rooms']=2

# %%
# посмотрим еще раз на квартиры с 0 комнатами
test.loc[test['Rooms']==0]
# видим что по величине Square и Price можно уточнить коли-чество комнат
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
test.loc[test['Id']==3343,'Rooms']=5
test.loc[test['Id']==10729,'Rooms']=3

# %%
# теперь разберемся с "аномально маленькими" Square
(test.loc[test['Rooms']==1]).loc[test['Square']<10]
# скорее всего это маленькая трешка с ошибкой в запятой
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
test.loc[(test['Rooms']==1)&(test['Square']<10),'Square']=test.loc[(test['Rooms']==1)&(test['Square']<10),'Square']*10
test.loc[(test['Rooms']==1)&(test['Square']<10),'LifeSquare']=test.loc[(test['Rooms']==1)&(test['Square']<10),'LifeSquare']*10

# %%
# проверяем как это все поменяла общую картину
test.describe()
# видно что появидись непонятные максимальные значения Square
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.908600    56.639292    35.979822
# std     4832.674037    44.179466     0.811405    19.326774    17.179153
# min        1.000000     0.000000     1.000000    13.305531     0.333490
# 25%     4221.750000    21.000000     1.000000    42.023090    23.091332
# 50%     8320.500000    37.000000     2.000000    52.957761    32.886142
# 75%    12598.250000    77.000000     2.000000    66.416189    45.070420
# max    16795.000000   212.000000     6.000000   303.071094   168.729035
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.584800  1984.392600     0.119874
# std         9.950018     5.483228     6.678752    18.573149     0.120070
# ...

# %%
test.loc[(test['Square']>140)&(test['Rooms']<4)]
# видим что соотношение Rooms Price с Square - не адекватные - ошибка с запятой
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 410   11533          94    2.0  303.071094   48.713443            6.0      5
# 870   13736          27    1.0  141.540215   91.704806           42.0      3
# 1264  13589          27    3.0  173.974480   76.289475            9.0      3
# 2039   3357          27    3.0  170.476326   75.973612            8.0      2
# 2371   1929          62    3.0  148.783492         NaN            0.0      5
# 3909   1397          76    3.0  221.138768  118.055342            4.0     32
# 4384  14498          23    1.0  163.325901         NaN            1.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 410         12.0       1974   0.521867         B         B        25
# 870          3.0       2013   0.014073         B         B         2
# 1264         3.0       2017   0.041116         B         B        53
# 2039         2.0       2017   0.041116         B         B        53
# ...

# %%
LifeSquare_11533 = test.loc[(test['Id']==11533),'Square']/10
test.loc[(test['Id']==11533),'Square']=test.loc[(test['Id']==11533),'LifeSquare']
test.loc[(test['Id']==11533),'LifeSquare']=LifeSquare_11533

# %% [markdown]
# - работа с частичными данными

# %% [markdown]
# ** Разберемся с кухнями

# %%
test.describe()
# уже по этим данным понятно что по меншей мере 50% данных не корректны (не может быть кухня 1 м2 )
# поэтому посчитаем среднее соотношение площади кухни к общей площади по данным где и рассчитаем значение для всех наблюдений
# где этот параметр меньше
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.908600    56.588421    35.975173
# std     4832.674037    44.179466     0.811405    19.010156    17.178197
# min        1.000000     0.000000     1.000000    13.305531     0.333490
# 25%     4221.750000    21.000000     1.000000    42.023090    23.091332
# 50%     8320.500000    37.000000     2.000000    52.933734    32.885357
# 75%    12598.250000    77.000000     2.000000    66.392939    45.058173
# max    16795.000000   212.000000     6.000000   223.453689   168.729035
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.584800  1984.392600     0.119874
# std         9.950018     5.483228     6.678752    18.573149     0.120070
# ...

# %%
# уберем явные описки чтобы прояснитькартину
test.loc[((test['KitchenSquare'])>30)&(test['Square']<100)]
# эти некорректные данные пополнят нулевые кухни
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 40     5428          27    2.0  62.326044         NaN           61.0     12
# 625    2249          62    1.0  78.281763   77.157675           34.0      5
# 1456   5260          73    3.0  69.358242   51.247581           65.0      6
# 1964  14594          11    2.0  42.795304   24.223770          620.0     11
# 2424  10662          29    1.0  25.956829   17.251768           33.0      5
# 3723   4483          62    1.0  45.672140   41.951462           41.0     13
# 3816  12612          27    2.0  60.988496   33.646726           60.0      5
# 3863   3194          29    2.0  43.926987   31.028707           44.0      6
# 3927   6568          78    1.0  46.827201   40.227011           40.0      5
# 4281   8015          27    1.0  66.099096   33.639611           62.0      3
# 4405   5199          27    2.0  61.647531   59.054990           57.0     13
# ...

# %%
test.loc[((test['KitchenSquare'])>30)&(test['Square']<100),'KitchenSquare']=0

# %%
test.loc[((test['KitchenSquare'])>50)&(test['Square']<300)]
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1777  3341          62    3.0  112.247841  112.114019          112.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1777         3.0       2017   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1777       629         1           NaN            0        0       A

# %%
test.loc[((test['KitchenSquare'])>50)&(test['Square']<300),'KitchenSquare']=0

# %%
# теперь посмотрим кухни меньше 3 и обнулим их как не корректные
test.loc[((test['KitchenSquare'])<4),'KitchenSquare']=0

# %%
test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.908600    56.588421    35.975173
# std     4832.674037    44.179466     0.811405    19.010156    17.178197
# min        1.000000     0.000000     1.000000    13.305531     0.333490
# 25%     4221.750000    21.000000     1.000000    42.023090    23.091332
# 50%     8320.500000    37.000000     2.000000    52.933734    32.885357
# 75%    12598.250000    77.000000     2.000000    66.392939    45.058173
# max    16795.000000   212.000000     6.000000   223.453689   168.729035
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.465200     8.632000    12.584800  1984.392600     0.119874
# std         4.253047     5.483228     6.678752    18.573149     0.120070
# ...

# %%
kitchen_data_t=test.loc[:,['Id','KitchenSquare','LifeSquare','Square','Rooms']]
tampl_t = kitchen_data_t.loc[(test['KitchenSquare']>0)].groupby(['Rooms']).mean()
print(tampl_t)
# Out:
#                  Id  KitchenSquare  LifeSquare      Square
# Rooms
# 1.0     8208.004480       7.756272   22.710760   39.377530
# 2.0     8484.555014       7.718663   33.870257   53.712913
# 3.0     8272.327160       8.386420   48.179019   74.076632
# 4.0     8626.341772       8.924051   63.348303   92.532328
# 5.0    11370.750000      18.000000   80.990940  127.804158
# 6.0     4058.000000      16.000000  104.113552  223.453689

# %%
# полученные нулевые значения заполним на основании соотношения в известных данных 
# KitchenSquare/Square с привязкой к количеству комнат
rooms_t = test['Rooms'].unique()
total_kitchen_koef_t=[]
for j in range(1,rooms_t.shape[0]+1):
    square_tot_kithen_t = test.loc[(test['KitchenSquare']>0)&(test['Rooms']==j)]['KitchenSquare'].mean()/test.loc[(test['KitchenSquare']>0)&(test['Rooms']==j)]['Square'].mean()
    total_kitchen_koef_t.append(square_tot_kithen_t)
total_kitchen_koef_t
# Out:
# [0.19697203718405729,
#  0.1437021843988666,
#  0.11321275729805313,
#  0.09644251671175458,
#  0.14084048766233456,
#  0.07160320371145591]

# %%
test.loc[(test['KitchenSquare']==0)&(test['Rooms']==1),'KitchenSquare']=test.loc[(test['KitchenSquare']==0)&(test['Rooms']==1),'Square']*total_kitchen_koef_t[0]
test.loc[(test['KitchenSquare']==0)&(test['Rooms']==2),'KitchenSquare']=test.loc[(test['KitchenSquare']==0)&(test['Rooms']==2),'Square']*total_kitchen_koef_t[1]
test.loc[(test['KitchenSquare']==0)&(test['Rooms']==3),'KitchenSquare']=test.loc[(test['KitchenSquare']==0)&(test['Rooms']==3),'Square']*total_kitchen_koef_t[2]
test.loc[(test['KitchenSquare']==0)&(test['Rooms']==4),'KitchenSquare']=test.loc[(test['KitchenSquare']==0)&(test['Rooms']==4),'Square']*total_kitchen_koef_t[3]
test.loc[(test['KitchenSquare']==0)&(test['Rooms']==5),'KitchenSquare']=test.loc[(test['KitchenSquare']==0)&(test['Rooms']==5),'Square']*total_kitchen_koef_t[4]
test.loc[(test['KitchenSquare']==0)&(test['Rooms']==6),'KitchenSquare']=test.loc[(test['KitchenSquare']==0)&(test['Rooms']==6),'Square']*total_kitchen_koef_t[5]

# %%
test.groupby(['Rooms']).mean()
# Out:
#                 Id  DistrictId      Square  LifeSquare  KitchenSquare  \
# Rooms
# 1.0    8376.291125   49.691916   41.165216   24.546782       8.108396
# 2.0    8494.522895   50.949778   56.802148   35.901141       8.162593
# 3.0    8319.376364   52.770000   77.260713   50.075091       8.746898
# 4.0    8407.777778   71.688889   94.526010   64.916940       9.116326
# 5.0    8759.625000   57.875000  115.918374   69.507522      16.326000
# 6.0    7425.500000   25.000000  167.101957  104.113552      11.965035
#
#           Floor  HouseFloor    HouseYear  Ecology_1   Social_1     Social_2  \
# Rooms
# 1.0    8.878462   12.791408  1985.986998   0.119710  23.955907  5214.457321
# 2.0    8.422452   12.422944  1982.651403   0.122290  24.504677  5276.964057
# 3.0    8.750909   12.560000  1984.888182   0.115930  26.602727  5785.793636
# 4.0    7.422222   12.888889  1985.688889   0.115665  33.177778  7327.844444
# 5.0    6.250000   10.625000  1983.250000   0.155372  27.250000  6670.625000
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
# Id               5000 non-null int64
# DistrictId       5000 non-null int64
# Rooms            5000 non-null float64
# Square           5000 non-null float64
# LifeSquare       3959 non-null float64
# KitchenSquare    5000 non-null float64
# Floor            5000 non-null int64
# HouseFloor       5000 non-null float64
# HouseYear        5000 non-null int64
# Ecology_1        5000 non-null float64
# Ecology_2        5000 non-null object
# Ecology_3        5000 non-null object
# Social_1         5000 non-null int64
# Social_2         5000 non-null int64
# Social_3         5000 non-null int64
# Healthcare_1     2623 non-null float64
# Helthcare_2      5000 non-null int64
# Shops_1          5000 non-null int64
# Shops_2          5000 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 742.3+ KB

# %% [markdown]
# **разберемся с LifeSquare

# %%
test.loc[test['LifeSquare']<10].describe()
# очевидно имеет место ошибка с запятой
# Out:
#                  Id  DistrictId       Rooms      Square  LifeSquare  \
# count    111.000000  111.000000  111.000000  111.000000  111.000000
# mean    6658.207207   30.081081    1.837838   63.480586    3.393118
# std     4683.770104   30.652936    0.939444   23.354777    1.715373
# min       37.000000    1.000000    1.000000   13.305531    0.333490
# 25%     2760.500000    6.000000    1.000000   46.306920    1.965792
# 50%     6150.000000   27.000000    2.000000   64.112441    3.013166
# 75%    10565.500000   45.000000    3.000000   79.103217    4.713618
# max    16722.000000  196.000000    5.000000  139.708806    9.698766
#
#        KitchenSquare       Floor  HouseFloor    HouseYear   Ecology_1  \
# count     111.000000  111.000000  111.000000   111.000000  111.000000
# mean        9.645721   10.189189   11.360360  1994.180180    0.138138
# std         2.740409    7.014937    9.164946    19.889329    0.119685
# min         2.620818    1.000000    0.000000  1965.000000    0.000000
# ...

# %%
test.loc[test['LifeSquare']<10, 'LifeSquare']=test.loc[test['LifeSquare']<10, 'LifeSquare']*10

# %%
# осталось еще часть квартир с не корретными данными 
test.loc[test['LifeSquare']<10]
# обнулим эти данные чтобы потом заменить их по формуле в зависимости от количества комнат
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 78    6553          34    5.0  122.375273         0.0      17.235393      9
# 2341  3028           9    1.0   43.348348         0.0       8.538412     16
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 78           0.0       1977   0.069753         B         B        53
# 2341        17.0       2015   0.161532         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 78       13670         4           NaN            1       11       B
# 2341      5648         1          30.0            2        4       B

# %%
LifeSquare_13014 = test.loc[(test['Id']==13014),'Square']
test.loc[(test['Id']==13014),'Square']=test.loc[(test['Id']==13014),'LifeSquare']*10
test.loc[(test['Id']==13014),'LifeSquare']=LifeSquare_13014

# %%
test.loc[(test['Id']==6406),'LifeSquare']=test.loc[(test['Id']==6406),'LifeSquare']*10

# %%
test.loc[test['LifeSquare']<10,'LifeSquare']=0

# %%
rooms_t = test['Rooms'].unique()
total_life_koef_t=[]
for j in range(1,rooms_t.shape[0]+1):
    square_tot_life_t = test.loc[(test['LifeSquare']>0)&(test['Rooms']==j)]['LifeSquare'].mean()/test.loc[(test['LifeSquare']>0)&(test['Rooms']==j)]['Square'].mean()
    total_life_koef_t.append(square_tot_life_t)
total_life_koef_t
# Out:
# [0.6385880528014382,
#  0.6670022504707043,
#  0.676417252943167,
#  0.6920091861942247,
#  0.7210256888896646,
#  0.4659289937141569]

# %%
test.loc[test['LifeSquare'].isna()].groupby(['Rooms']).mean()
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1]
# Index: []

# %%
# исправил нулевые LifeSquare
test.loc[(test['LifeSquare']==0)&(test['Rooms']==1),'LifeSquare']=test.loc[(test['LifeSquare']==0)&(test['Rooms']==1),'Square']*total_life_koef_t[0]
test.loc[(test['LifeSquare']==0)&(test['Rooms']==5),'LifeSquare']=test.loc[(test['LifeSquare']==0)&(test['Rooms']==5),'Square']*total_life_koef_t[4]

# %%
# исправил NaN LifeSquare
test.loc[(test['LifeSquare'].isna())&(test['Rooms']==1),'LifeSquare']=test.loc[(test['LifeSquare'].isna())&(test['Rooms']==1),'Square']*total_life_koef_t[0]
test.loc[(test['LifeSquare'].isna())&(test['Rooms']==2),'LifeSquare']=test.loc[(test['LifeSquare'].isna())&(test['Rooms']==2),'Square']*total_life_koef_t[1]
test.loc[(test['LifeSquare'].isna())&(test['Rooms']==3),'LifeSquare']=test.loc[(test['LifeSquare'].isna())&(test['Rooms']==3),'Square']*total_life_koef_t[2]
test.loc[(test['LifeSquare'].isna())&(test['Rooms']==4),'LifeSquare']=test.loc[(test['LifeSquare'].isna())&(test['Rooms']==4),'Square']*total_life_koef_t[3]
test.loc[(test['LifeSquare'].isna())&(test['Rooms']==5),'LifeSquare']=test.loc[(test['LifeSquare'].isna())&(test['Rooms']==5),'Square']*total_life_koef_t[4]
test.loc[(test['LifeSquare'].isna())&(test['Rooms']==6),'LifeSquare']=test.loc[(test['LifeSquare'].isna())&(test['Rooms']==6),'Square']*total_life_koef_t[5]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
# Id               5000 non-null int64
# DistrictId       5000 non-null int64
# Rooms            5000 non-null float64
# Square           5000 non-null float64
# LifeSquare       5000 non-null float64
# KitchenSquare    5000 non-null float64
# Floor            5000 non-null int64
# HouseFloor       5000 non-null float64
# HouseYear        5000 non-null int64
# Ecology_1        5000 non-null float64
# Ecology_2        5000 non-null object
# Ecology_3        5000 non-null object
# Social_1         5000 non-null int64
# Social_2         5000 non-null int64
# Social_3         5000 non-null int64
# Healthcare_1     2623 non-null float64
# Helthcare_2      5000 non-null int64
# Shops_1          5000 non-null int64
# Shops_2          5000 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 742.3+ KB

# %%
# обучим на имеющихся данных метод и предположим данные для недостающих наблюдени
# разделим всю дата базу на базу с данными по Healthcare_1

# %%
Healthcare_1_test_t = test.loc[test['Healthcare_1'].isna()]
Healthcare_1_test_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2377 entries, 0 to 4998
# Data columns (total 19 columns):
# Id               2377 non-null int64
# DistrictId       2377 non-null int64
# Rooms            2377 non-null float64
# Square           2377 non-null float64
# LifeSquare       2377 non-null float64
# KitchenSquare    2377 non-null float64
# Floor            2377 non-null int64
# HouseFloor       2377 non-null float64
# HouseYear        2377 non-null int64
# Ecology_1        2377 non-null float64
# Ecology_2        2377 non-null object
# Ecology_3        2377 non-null object
# Social_1         2377 non-null int64
# Social_2         2377 non-null int64
# Social_3         2377 non-null int64
# Healthcare_1     0 non-null float64
# Helthcare_2      2377 non-null int64
# Shops_1          2377 non-null int64
# Shops_2          2377 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 371.4+ KB

# %%
Healthcare_1_data_t = test.loc[test['Healthcare_1']>=0]
Healthcare_1_data_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2623 entries, 2 to 4999
# Data columns (total 19 columns):
# Id               2623 non-null int64
# DistrictId       2623 non-null int64
# Rooms            2623 non-null float64
# Square           2623 non-null float64
# LifeSquare       2623 non-null float64
# KitchenSquare    2623 non-null float64
# Floor            2623 non-null int64
# HouseFloor       2623 non-null float64
# HouseYear        2623 non-null int64
# Ecology_1        2623 non-null float64
# Ecology_2        2623 non-null object
# Ecology_3        2623 non-null object
# Social_1         2623 non-null int64
# Social_2         2623 non-null int64
# Social_3         2623 non-null int64
# Healthcare_1     2623 non-null float64
# Helthcare_2      2623 non-null int64
# Shops_1          2623 non-null int64
# Shops_2          2623 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 409.8+ KB

# %%
# а базу с данными по Healthcare_1 на тестовую и валидационную
train_h1_t,valid_h1_t=train_test_split(Healthcare_1_data_t,test_size=0.25, random_state=42)
train_h1_t.shape, valid_h1_t.shape
# Out:
# ((1967, 19), (656, 19))

# %%
# хорошая зависимость с 'DistrictId','HouseYear','Social_1', 'Social_2', 
# 'Social_3','Helthcare_2', 'Shops_1', 'Price'
#  будем использовать это при обучении
feats_for_h1_t=['DistrictId','HouseYear','Social_1', 'Social_2','Social_3','Helthcare_2', 'Shops_1']
model_for_h1_t=RF(n_estimators=100,max_depth=30,random_state=42)

# %%
# обучение
model_for_h1_t.fit(train_h1_t.loc[:,feats_for_h1_t],train_h1_t['Healthcare_1'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=30,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
# предсказание
y_pred_h1_t=model_for_h1_t.predict(valid_h1_t.loc[:,feats_for_h1_t])

# %%
# оценка на валиде
r2(valid_h1_t['Healthcare_1'],y_pred_h1_t)
# Out:
# 0.9968840876775866

# %%
# оценка на трэйне
r2(train_h1_t['Healthcare_1'],model_for_h1_t.predict(train_h1_t.loc[:,feats_for_h1_t]))
# Out:
# 0.9992056116458782

# %%
# создание данных - на "тесте" и добавление данных в data как новая колонка
Healthcare_1_test_t['Healthcare_1']=model_for_h1_t.predict(Healthcare_1_test_t.loc[:,feats_for_h1_t])
Healthcare_1_test_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2377 entries, 0 to 4998
# Data columns (total 19 columns):
# Id               2377 non-null int64
# DistrictId       2377 non-null int64
# Rooms            2377 non-null float64
# Square           2377 non-null float64
# LifeSquare       2377 non-null float64
# KitchenSquare    2377 non-null float64
# Floor            2377 non-null int64
# HouseFloor       2377 non-null float64
# HouseYear        2377 non-null int64
# Ecology_1        2377 non-null float64
# Ecology_2        2377 non-null object
# Ecology_3        2377 non-null object
# Social_1         2377 non-null int64
# Social_2         2377 non-null int64
# Social_3         2377 non-null int64
# Healthcare_1     2377 non-null float64
# Helthcare_2      2377 non-null int64
# Shops_1          2377 non-null int64
# Shops_2          2377 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 371.4+ KB

# %%
Healthcare_1_test_t.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   2377.000000  2377.000000  2377.000000  2377.000000  2377.000000
# mean    8375.120320    43.686580     1.895667    58.054808    38.968772
# std     4821.770095    38.337733     0.822179    19.879831    16.712809
# min        1.000000     1.000000     1.000000    17.273699    10.692499
# 25%     4224.000000    23.000000     1.000000    42.718235    26.426549
# 50%     8265.000000    27.000000     2.000000    54.584237    35.412723
# 75%    12516.000000    62.000000     2.000000    67.076013    47.251104
# max    16789.000000   210.000000     6.000000   223.453689   136.921090
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    2377.000000  2377.000000  2377.000000  2377.000000  2377.000000
# mean        8.660212     8.977282    12.972655  1987.599074     0.090455
# std         2.486730     5.439937     6.856245    17.660792     0.104087
# ...

# %%
# a подсуним вместо Healthcare_1_test настоящую data
test.loc[test['Healthcare_1'].isna(), 'Healthcare_1']=model_for_h1_t.predict(Healthcare_1_test_t.loc[:,feats_for_h1_t])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
# Id               5000 non-null int64
# DistrictId       5000 non-null int64
# Rooms            5000 non-null float64
# Square           5000 non-null float64
# LifeSquare       5000 non-null float64
# KitchenSquare    5000 non-null float64
# Floor            5000 non-null int64
# HouseFloor       5000 non-null float64
# HouseYear        5000 non-null int64
# Ecology_1        5000 non-null float64
# Ecology_2        5000 non-null object
# Ecology_3        5000 non-null object
# Social_1         5000 non-null int64
# Social_2         5000 non-null int64
# Social_3         5000 non-null int64
# Healthcare_1     5000 non-null float64
# Helthcare_2      5000 non-null int64
# Shops_1          5000 non-null int64
# Shops_2          5000 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 742.3+ KB

# %% [markdown]
# ### - внесение изменений в тестовую базу (добавление синтетических признаков)

# %%
test_scaled=scaler.transform(test.loc[:,['Square','DistrictId']])
test['cluster_Square']=knn.predict(test_scaled)

# %%
test['Price']=model.predict(test.loc[:,feats])

# %%
test.loc[:,['Id','Price']].to_csv('AKhimchenko_predictions.csv',index=None)

# %%
pd.read_csv('AKhimchenko_predictions.csv')
# Out:
#          Id          Price
# 0       725  164720.667885
# 1     15856  214684.437366
# 2      5480  198228.278234
# 3     15664  322881.264179
# 4     14275  140214.478003
# 5      7633  197608.538447
# 6     13329  178288.257511
# 7      5502  222773.479725
# 8      4220  292903.274956
# 9     11538  208987.367371
# 10    15975  267017.882387
# 11     3310  216053.642275
# 12     9286  152821.479484
# 13    11260  198661.431344
# 14     5214  102086.431743
# 15    11307  183795.596961
# 16    13543  378094.683551
# 17      615  179386.011401
# 18     3495  233455.179606
# 19     2321  241970.949223
# 20    12046  181928.836736
# 21    16688  145336.062146
# 22    12694  230087.588197
# 23      783  160501.756101
# 24     8968  166368.663454
# 25    13454  184743.153599
# 26    12190  284875.605453
# 27    11160  119782.755316
# 28    10291  206942.460439
# 29      891  275196.709528
# ...     ...            ...
# 4970   1740  197864.044307
# 4971   3450  149142.327766
# ...
